# %% [markdown]
# ### QED-C Prototype Benchmarks - Qiskit Version
# The notebook contains a suite of prototype application benchmarks for the IBM Qiskit API, along with the volumetric and the algorithmic qubit (AQ) measurement.
# Configure and run the cell below with the desired execution settings.
# Then execute the remaining cells, each containing one prototype benchmark program.

# %%
min_qubits=2
max_qubits=8
max_circuits=3
num_shots=2500

backend_id="qasm_simulator"
hub="ibm-q"; group="open"; project="main"
provider_backend = None
exec_options = None

# # *** If using IBMQ hardware, run this once to authenticate
# from qiskit import IBMQ
# IBMQ.save_account('YOUR_API_TOKEN_HERE')

# # *** If you are part of an IBMQ group, set hub, group, and project name here
# hub="YOUR_HUB_NAME"
# group="YOUR_GROUP_NAME"
# project="YOUR_PROJECT_NAME"

# # *** This example shows how to specify the backend using a known "backend_id"
# # Use 'sabre' layout for IBM backends
# exec_options = { "optimization_level":3, "layout_method":'sabre', "routing_method":'sabre' }
# backend_id="ibmq_belem"

# # *** Here's an example of using a typical custom provider backend (e.g. AQT simulator)
# import os
# from qiskit_aqt_provider import AQTProvider
# provider = AQTProvider(os.environ.get('AQT_ACCESS_KEY'))    # get your key from environment
# provider_backend = provider.backends.aqt_qasm_simulator_noise_1
# backend_id="aqt_qasm_simulator_noise_1"

# # An example using IonQ provider
# from qiskit_ionq import IonQProvider
# provider = IonQProvider()   # Be sure to set the QISKIT_IONQ_API_TOKEN environment variable
# provider_backend = provider.get_backend("ionq_qpu")
# backend_id="ionq_qpu"

# # *** Use these lines when running on hardware backend, to limit use of resources
# min_qubits=2
# max_qubits=5
# max_circuits=1
# num_shots=100

# %%
#%run quantum-fourier-transform/qiskit/qft_benchmark.py
import sys
sys.path.insert(1, "quantum-fourier-transform/qiskit")
import qft_benchmark
min_qubits=6
max_qubits=15
qft_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, max_circuits=max_circuits, num_shots=num_shots,
                method=1,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Quantum Fourier Transform Benchmark Program - Qiskit
# ... using circuit method 1
# ... execution starting at 2023-10-16 17:07:01
# ************
# Executing [3] circuits with num_qubits = 6
# ... number of gates, depth = 58, 44
# ************
# Executing [3] circuits with num_qubits = 7
# ... number of gates, depth = 74, 58
# ************
# Executing [3] circuits with num_qubits = 8
# ... number of gates, depth = 92, 74
# ************
# Average Depth, ξ (xi) for the 6 qubit group = 45, 0.577
# Average Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 122, 0.39, 60.0
# Average Creation Time for the 6 qubit group = 0.002 secs
# Average Elapsed Time for the 6 qubit group = 1.073 secs
# Average Execution Time for the 6 qubit group = 0.016 secs
# Average Fidelity for the 6 qubit group = 0.23
# Average AQ Fidelity for the 6 qubit group = 0.242
#
# ************
# Executing [3] circuits with num_qubits = 9
# ... number of gates, depth = 111, 92
# ************
# Average Depth, ξ (xi) for the 7 qubit group = 59, 0.64
# Average Transpiled Depth, ξ (xi), 2q gates for the 7 qubit group = 163, 0.408, 84.0
# Average Creation Time for the 7 qubit group = 0.002 secs
# Average Elapsed Time for the 7 qubit group = 1.887 secs
# Average Execution Time for the 7 qubit group = 0.033 secs
# Average Fidelity for the 7 qubit group = 0.135
# Average AQ Fidelity for the 7 qubit group = 0.142
#
# ************
# Executing [3] circuits with num_qubits = 10
# ... number of gates, depth = 134, 112
# ************
# Average Depth, ξ (xi) for the 8 qubit group = 75, 0.664
# Average Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 210, 0.417, 112.0
# Average Creation Time for the 8 qubit group = 0.003 secs
# Average Elapsed Time for the 8 qubit group = 2.586 secs
# Average Execution Time for the 8 qubit group = 0.019 secs
# Average Fidelity for the 8 qubit group = 0.071
# Average AQ Fidelity for the 8 qubit group = 0.075
#
# ************
# Executing [3] circuits with num_qubits = 11
# ... number of gates, depth = 160, 134
# ************
# Average Depth, ξ (xi) for the 9 qubit group = 93, 0.701
# Average Transpiled Depth, ξ (xi), 2q gates for the 9 qubit group = 263, 0.428, 144.0
# Average Creation Time for the 9 qubit group = 0.004 secs
# Average Elapsed Time for the 9 qubit group = 3.564 secs
# Average Execution Time for the 9 qubit group = 0.04 secs
# Average Fidelity for the 9 qubit group = 0.041
# Average AQ Fidelity for the 9 qubit group = 0.043
#
# ************
# Executing [3] circuits with num_qubits = 12
# ... number of gates, depth = 187, 158
# ************
# Average Depth, ξ (xi) for the 10 qubit group = 113, 0.718
# Average Transpiled Depth, ξ (xi), 2q gates for the 10 qubit group = 322, 0.433, 180.0
# Average Creation Time for the 10 qubit group = 0.004 secs
# Average Elapsed Time for the 10 qubit group = 6.802 secs
# Average Execution Time for the 10 qubit group = 0.144 secs
# Average Fidelity for the 10 qubit group = 0.017
# Average AQ Fidelity for the 10 qubit group = 0.018
#
# ************
# Executing [3] circuits with num_qubits = 13
# ... number of gates, depth = 212, 184
# ************
# Average Depth, ξ (xi) for the 11 qubit group = 135, 0.743
# Average Transpiled Depth, ξ (xi), 2q gates for the 11 qubit group = 387, 0.44, 220.0
# Average Creation Time for the 11 qubit group = 0.006 secs
# Average Elapsed Time for the 11 qubit group = 10.296 secs
# Average Execution Time for the 11 qubit group = 1.193 secs
# Average Fidelity for the 11 qubit group = 0.01
# Average AQ Fidelity for the 11 qubit group = 0.011
#
# ************
# Executing [3] circuits with num_qubits = 14
# ... number of gates, depth = 245, 212
# ************
# Average Depth, ξ (xi) for the 12 qubit group = 159, 0.759
# Average Transpiled Depth, ξ (xi), 2q gates for the 12 qubit group = 458, 0.444, 264.0
# Average Creation Time for the 12 qubit group = 0.006 secs
# Average Elapsed Time for the 12 qubit group = 16.327 secs
# Average Execution Time for the 12 qubit group = 1.464 secs
# Average Fidelity for the 12 qubit group = 0.004
# Average AQ Fidelity for the 12 qubit group = 0.005
#
# ************
# Executing [3] circuits with num_qubits = 15
# ... number of gates, depth = 282, 242
# ************
# Average Depth, ξ (xi) for the 13 qubit group = 185, 0.779
# Average Transpiled Depth, ξ (xi), 2q gates for the 13 qubit group = 535, 0.449, 312.0
# Average Creation Time for the 13 qubit group = 0.006 secs
# Average Elapsed Time for the 13 qubit group = 28.236 secs
# Average Execution Time for the 13 qubit group = 2.878 secs
# Average Fidelity for the 13 qubit group = 0.002
# Average AQ Fidelity for the 13 qubit group = 0.002
#
# ************
# Average Depth, ξ (xi) for the 14 qubit group = 213, 0.788
# Average Transpiled Depth, ξ (xi), 2q gates for the 14 qubit group = 618, 0.452, 364.0
# Average Creation Time for the 14 qubit group = 0.042 secs
# Average Elapsed Time for the 14 qubit group = 30.405 secs
# Average Execution Time for the 14 qubit group = 6.132 secs
# Average Fidelity for the 14 qubit group = 0.001
# Average AQ Fidelity for the 14 qubit group = 0.001
#
# ************
# Average Depth, ξ (xi) for the 15 qubit group = 243, 0.793
# Average Transpiled Depth, ξ (xi), 2q gates for the 15 qubit group = 707, 0.454, 420.0
# Average Creation Time for the 15 qubit group = 0.009 secs
# Average Elapsed Time for the 15 qubit group = 14.42 secs
# Average Execution Time for the 15 qubit group = 5.772 secs
# Average Fidelity for the 15 qubit group = 0.0
# Average AQ Fidelity for the 15 qubit group = 0.0
#
# ... execution complete at 2023-10-16 17:08:13
#
# Sample Circuit:
#       ┌───┐ ░ ┌──────┐ ░  ┌───────┐   ░ ┌──────────┐ ░ ┌─┐
# q0_0: ┤ X ├─░─┤0     ├─░──┤ Rz(π) ├───░─┤0         ├─░─┤M├───────────────
#       └───┘ ░ │      │ ░ ┌┴───────┴┐  ░ │          │ ░ └╥┘┌─┐
# q0_1: ──────░─┤1     ├─░─┤ Rz(π/2) ├──░─┤1         ├─░──╫─┤M├────────────
#       ┌───┐ ░ │      │ ░ ├─────────┤  ░ │          │ ░  ║ └╥┘┌─┐
# q0_2: ┤ X ├─░─┤2     ├─░─┤ Rz(π/4) ├──░─┤2         ├─░──╫──╫─┤M├─────────
#       ├───┤ ░ │  qft │ ░ ├─────────┤  ░ │  inv_qft │ ░  ║  ║ └╥┘┌─┐
# q0_3: ┤ X ├─░─┤3     ├─░─┤ Rz(π/8) ├──░─┤3         ├─░──╫──╫──╫─┤M├──────
#       └───┘ ░ │      │ ░ ├─────────┴┐ ░ │          │ ░  ║  ║  ║ └╥┘┌─┐
# q0_4: ──────░─┤4     ├─░─┤ Rz(π/16) ├─░─┤4         ├─░──╫──╫──╫──╫─┤M├───
#       ┌───┐ ░ │      │ ░ ├──────────┤ ░ │          │ ░  ║  ║  ║  ║ └╥┘┌─┐
# q0_5: ┤ X ├─░─┤5     ├─░─┤ Rz(π/32) ├─░─┤5         ├─░──╫──╫──╫──╫──╫─┤M├
#       └───┘ ░ └──────┘ ░ └──────────┘ ░ └──────────┘ ░  ║  ║  ║  ║  ║ └╥┘
# c0: 6/══════════════════════════════════════════════════╩══╩══╩══╩══╩══╩═
#                                                         0  1  2  3  4  5
#
# QFT Circuit =
#             ░                  ░                             ░            »
# q1_0: ──────░──────────────────░─────────────────────────────░────────────»
#             ░                  ░                             ░            »
# q1_1: ──────░──────────────────░─────────────────────────────░────────────»
#             ░                  ░                             ░            »
# q1_2: ──────░──────────────────░─────────────────────────────░──────■─────»
#             ░                  ░                       ┌───┐ ░      │     »
# q1_3: ──────░──────────────────░──────■──────────■─────┤ H ├─░──────┼─────»
#             ░            ┌───┐ ░      │     ┌────┴────┐└───┘ ░      │     »
# q1_4: ──────░──────■─────┤ H ├─░──────┼─────┤ Rz(π/2) ├──────░──────┼─────»
#       ┌───┐ ░ ┌────┴────┐└───┘ ░ ┌────┴────┐└─────────┘      ░ ┌────┴────┐»
# q1_5: ┤ H ├─░─┤ Rz(π/2) ├──────░─┤ Rz(π/4) ├─────────────────░─┤ Rz(π/8) ├»
#       └───┘ ░ └─────────┘      ░ └─────────┘                 ░ └─────────┘»
# «                                  ░                                   »
# «q1_0: ────────────────────────────░───────────────────────────────────»
# «                                  ░                                   »
# «q1_1: ────────────────────────────░──────■───────────■──────────■─────»
# «                            ┌───┐ ░      │           │          │     »
# «q1_2: ─────■──────────■─────┤ H ├─░──────┼───────────┼──────────┼─────»
# «           │     ┌────┴────┐└───┘ ░      │           │     ┌────┴────┐»
# «q1_3: ─────┼─────┤ Rz(π/2) ├──────░──────┼───────────┼─────┤ Rz(π/4) ├»
# «      ┌────┴────┐└─────────┘      ░      │      ┌────┴────┐└─────────┘»
# «q1_4: ┤ Rz(π/4) ├─────────────────░──────┼──────┤ Rz(π/8) ├───────────»
# «      └─────────┘                 ░ ┌────┴─────┐└─────────┘           »
# «q1_5: ────────────────────────────░─┤ Rz(π/16) ├──────────────────────»
# «                                  ░ └──────────┘                      »
# «                       ░                                               »
# «q1_0: ─────────────────░──────■───────────■───────────■──────────■─────»
# «                 ┌───┐ ░      │           │           │          │     »
# «q1_1: ─────■─────┤ H ├─░──────┼───────────┼───────────┼──────────┼─────»
# «      ┌────┴────┐└───┘ ░      │           │           │     ┌────┴────┐»
# «q1_2: ┤ Rz(π/2) ├──────░──────┼───────────┼───────────┼─────┤ Rz(π/4) ├»
# «      └─────────┘      ░      │           │      ┌────┴────┐└─────────┘»
# «q1_3: ─────────────────░──────┼───────────┼──────┤ Rz(π/8) ├───────────»
# «                       ░      │      ┌────┴─────┐└─────────┘           »
# «q1_4: ─────────────────░──────┼──────┤ Rz(π/16) ├──────────────────────»
# «                       ░ ┌────┴─────┐└──────────┘                      »
# «q1_5: ─────────────────░─┤ Rz(π/32) ├──────────────────────────────────»
# «                       ░ └──────────┘                                  »
# «                 ┌───┐ ░
# «q1_0: ─────■─────┤ H ├─░─
# «      ┌────┴────┐└───┘ ░
# «q1_1: ┤ Rz(π/2) ├──────░─
# «      └─────────┘      ░
# «q1_2: ─────────────────░─
# «                       ░
# «q1_3: ─────────────────░─
# «                       ░
# «q1_4: ─────────────────░─
# «                       ░
# «q1_5: ─────────────────░─
# «                       ░
#
# Inverse QFT Circuit =
#       ┌───┐                                                               ░ »
# q2_0: ┤ H ├─────■───────────■───────────■────────────■────────────■───────░─»
#       └───┘┌────┴─────┐     │           │            │            │       ░ »
# q2_1: ─────┤ Rz(-π/2) ├─────┼───────────┼────────────┼────────────┼───────░─»
#            └──────────┘┌────┴─────┐     │            │            │       ░ »
# q2_2: ─────────────────┤ Rz(-π/4) ├─────┼────────────┼────────────┼───────░─»
#                        └──────────┘┌────┴─────┐      │            │       ░ »
# q2_3: ─────────────────────────────┤ Rz(-π/8) ├──────┼────────────┼───────░─»
#                                    └──────────┘┌─────┴─────┐      │       ░ »
# q2_4: ─────────────────────────────────────────┤ Rz(-π/16) ├──────┼───────░─»
#                                                └───────────┘┌─────┴─────┐ ░ »
# q2_5: ──────────────────────────────────────────────────────┤ Rz(-π/32) ├─░─»
#                                                             └───────────┘ ░ »
# «                                                             ░      »
# «q2_0: ───────────────────────────────────────────────────────░──────»
# «      ┌───┐                                                  ░      »
# «q2_1: ┤ H ├─────■───────────■───────────■────────────■───────░──────»
# «      └───┘┌────┴─────┐     │           │            │       ░ ┌───┐»
# «q2_2: ─────┤ Rz(-π/2) ├─────┼───────────┼────────────┼───────░─┤ H ├»
# «           └──────────┘┌────┴─────┐     │            │       ░ └───┘»
# «q2_3: ─────────────────┤ Rz(-π/4) ├─────┼────────────┼───────░──────»
# «                       └──────────┘┌────┴─────┐      │       ░      »
# «q2_4: ─────────────────────────────┤ Rz(-π/8) ├──────┼───────░──────»
# «                                   └──────────┘┌─────┴─────┐ ░      »
# «q2_5: ─────────────────────────────────────────┤ Rz(-π/16) ├─░──────»
# «                                               └───────────┘ ░      »
# «                                           ░                               ░ »
# «q2_0: ─────────────────────────────────────░───────────────────────────────░─»
# «                                           ░                               ░ »
# «q2_1: ─────────────────────────────────────░───────────────────────────────░─»
# «                                           ░                               ░ »
# «q2_2: ─────■───────────■───────────■───────░───────────────────────────────░─»
# «      ┌────┴─────┐     │           │       ░ ┌───┐                         ░ »
# «q2_3: ┤ Rz(-π/2) ├─────┼───────────┼───────░─┤ H ├─────■───────────■───────░─»
# «      └──────────┘┌────┴─────┐     │       ░ └───┘┌────┴─────┐     │       ░ »
# «q2_4: ────────────┤ Rz(-π/4) ├─────┼───────░──────┤ Rz(-π/2) ├─────┼───────░─»
# «                  └──────────┘┌────┴─────┐ ░      └──────────┘┌────┴─────┐ ░ »
# «q2_5: ────────────────────────┤ Rz(-π/8) ├─░──────────────────┤ Rz(-π/4) ├─░─»
# «                              └──────────┘ ░                  └──────────┘ ░ »
# «                        ░       ░
# «q2_0: ──────────────────░───────░─
# «                        ░       ░
# «q2_1: ──────────────────░───────░─
# «                        ░       ░
# «q2_2: ──────────────────░───────░─
# «                        ░       ░
# «q2_3: ──────────────────░───────░─
# «      ┌───┐             ░       ░
# «q2_4: ┤ H ├─────■───────░───────░─
# «      └───┘┌────┴─────┐ ░ ┌───┐ ░
# «q2_5: ─────┤ Rz(-π/2) ├─░─┤ H ├─░─
# «           └──────────┘ ░ └───┘ ░

# %%
#%run phase-estimation/qiskit/pe_benchmark.py
import sys
sys.path.insert(1, "phase-estimation/qiskit")
import pe_benchmark
min_qubits=6
max_qubits=20
pe_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, max_circuits=max_circuits, num_shots=num_shots,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Phase Estimation Benchmark Program - Qiskit
# ... execution starting at 2023-10-16 17:08:15
# ************
# Executing [3] circuits with num_qubits = 6
# ************
# Executing [3] circuits with num_qubits = 7
# ************
# Executing [3] circuits with num_qubits = 8
# ************
# Average Depth, ξ (xi) for the 6 qubit group = 58, 0.395
# Average Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 59, 0.344, 27.333
# Average Creation Time for the 6 qubit group = 0.008 secs
# Average Elapsed Time for the 6 qubit group = 0.87 secs
# Average Execution Time for the 6 qubit group = 0.013 secs
# Average Fidelity for the 6 qubit group = 0.518
# Average AQ Fidelity for the 6 qubit group = 0.533
#
# ************
# Executing [3] circuits with num_qubits = 9
# ************
# Average Depth, ξ (xi) for the 7 qubit group = 78, 0.408
# Average Transpiled Depth, ξ (xi), 2q gates for the 7 qubit group = 82, 0.364, 40.667
# Average Creation Time for the 7 qubit group = 0.017 secs
# Average Elapsed Time for the 7 qubit group = 1.469 secs
# Average Execution Time for the 7 qubit group = 0.022 secs
# Average Fidelity for the 7 qubit group = 0.382
# Average AQ Fidelity for the 7 qubit group = 0.391
#
# ************
# Executing [3] circuits with num_qubits = 10
# ************
# Average Depth, ξ (xi) for the 8 qubit group = 101, 0.418
# Average Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 109, 0.378, 56.0
# Average Creation Time for the 8 qubit group = 0.011 secs
# Average Elapsed Time for the 8 qubit group = 2.158 secs
# Average Execution Time for the 8 qubit group = 0.02 secs
# Average Fidelity for the 8 qubit group = 0.269
# Average AQ Fidelity for the 8 qubit group = 0.275
#
# ************
# Executing [3] circuits with num_qubits = 11
# ************
# Average Depth, ξ (xi) for the 9 qubit group = 127, 0.426
# Average Transpiled Depth, ξ (xi), 2q gates for the 9 qubit group = 127, 0.388, 67.333
# Average Creation Time for the 9 qubit group = 0.008 secs
# Average Elapsed Time for the 9 qubit group = 2.726 secs
# Average Execution Time for the 9 qubit group = 0.022 secs
# Average Fidelity for the 9 qubit group = 0.206
# Average AQ Fidelity for the 9 qubit group = 0.209
#
# ************
# Executing [3] circuits with num_qubits = 12
# ************
# Average Depth, ξ (xi) for the 10 qubit group = 156, 0.433
# Average Transpiled Depth, ξ (xi), 2q gates for the 10 qubit group = 163, 0.398, 88.667
# Average Creation Time for the 10 qubit group = 0.008 secs
# Average Elapsed Time for the 10 qubit group = 4.176 secs
# Average Execution Time for the 10 qubit group = 0.102 secs
# Average Fidelity for the 10 qubit group = 0.119
# Average AQ Fidelity for the 10 qubit group = 0.121
#
# ************
# Executing [3] circuits with num_qubits = 13
# ************
# Average Depth, ξ (xi) for the 11 qubit group = 188, 0.438
# Average Transpiled Depth, ξ (xi), 2q gates for the 11 qubit group = 196, 0.406, 108.667
# Average Creation Time for the 11 qubit group = 0.01 secs
# Average Elapsed Time for the 11 qubit group = 6.431 secs
# Average Execution Time for the 11 qubit group = 0.593 secs
# Average Fidelity for the 11 qubit group = 0.082
# Average AQ Fidelity for the 11 qubit group = 0.083
#
# ************
# Executing [3] circuits with num_qubits = 14
# ************
# Average Depth, ξ (xi) for the 12 qubit group = 223, 0.443
# Average Transpiled Depth, ξ (xi), 2q gates for the 12 qubit group = 235, 0.412, 132.0
# Average Creation Time for the 12 qubit group = 0.01 secs
# Average Elapsed Time for the 12 qubit group = 10.27 secs
# Average Execution Time for the 12 qubit group = 0.861 secs
# Average Fidelity for the 12 qubit group = 0.047
# Average AQ Fidelity for the 12 qubit group = 0.047
#
# ************
# Executing [3] circuits with num_qubits = 15
# ************
# Average Depth, ξ (xi) for the 13 qubit group = 261, 0.447
# Average Transpiled Depth, ξ (xi), 2q gates for the 13 qubit group = 270, 0.418, 154.0
# Average Creation Time for the 13 qubit group = 0.011 secs
# Average Elapsed Time for the 13 qubit group = 17.399 secs
# Average Execution Time for the 13 qubit group = 1.705 secs
# Average Fidelity for the 13 qubit group = 0.034
# Average AQ Fidelity for the 13 qubit group = 0.034
#
# ************
# Executing [3] circuits with num_qubits = 16
# ************
# Average Depth, ξ (xi) for the 14 qubit group = 302, 0.45
# Average Transpiled Depth, ξ (xi), 2q gates for the 14 qubit group = 315, 0.423, 181.333
# Average Creation Time for the 14 qubit group = 0.012 secs
# Average Elapsed Time for the 14 qubit group = 22.07 secs
# Average Execution Time for the 14 qubit group = 3.631 secs
# Average Fidelity for the 14 qubit group = 0.017
# Average AQ Fidelity for the 14 qubit group = 0.017
#
# ************
# Executing [3] circuits with num_qubits = 17
# ************
# Average Depth, ξ (xi) for the 15 qubit group = 346, 0.454
# Average Transpiled Depth, ξ (xi), 2q gates for the 15 qubit group = 357, 0.428, 208.0
# Average Creation Time for the 15 qubit group = 0.049 secs
# Average Elapsed Time for the 15 qubit group = 32.601 secs
# Average Execution Time for the 15 qubit group = 3.404 secs
# Average Fidelity for the 15 qubit group = 0.008
# Average AQ Fidelity for the 15 qubit group = 0.008
#
# ************
# Executing [3] circuits with num_qubits = 18
# ************
# Average Depth, ξ (xi) for the 16 qubit group = 393, 0.456
# Average Transpiled Depth, ξ (xi), 2q gates for the 16 qubit group = 402, 0.432, 236.667
# Average Creation Time for the 16 qubit group = 0.015 secs
# Average Elapsed Time for the 16 qubit group = 63.78 secs
# Average Execution Time for the 16 qubit group = 6.461 secs
# Average Fidelity for the 16 qubit group = 0.005
# Average AQ Fidelity for the 16 qubit group = 0.005
#
# ************
# Executing [3] circuits with num_qubits = 19
# ************
# Average Depth, ξ (xi) for the 17 qubit group = 443, 0.459
# Average Transpiled Depth, ξ (xi), 2q gates for the 17 qubit group = 460, 0.435, 272.0
# Average Creation Time for the 17 qubit group = 0.015 secs
# Average Elapsed Time for the 17 qubit group = 141.852 secs
# Average Execution Time for the 17 qubit group = 13.405 secs
# Average Fidelity for the 17 qubit group = 0.002
# Average AQ Fidelity for the 17 qubit group = 0.002
#
# ************
# Executing [3] circuits with num_qubits = 20
# ************
# Average Depth, ξ (xi) for the 18 qubit group = 496, 0.461
# Average Transpiled Depth, ξ (xi), 2q gates for the 18 qubit group = 513, 0.438, 305.333
# Average Creation Time for the 18 qubit group = 0.017 secs
# Average Elapsed Time for the 18 qubit group = 330.385 secs
# Average Execution Time for the 18 qubit group = 31.568 secs
# Average Fidelity for the 18 qubit group = 0.001
# Average AQ Fidelity for the 18 qubit group = 0.001
#
# ************
# Average Depth, ξ (xi) for the 19 qubit group = 552, 0.463
# Average Transpiled Depth, ξ (xi), 2q gates for the 19 qubit group = 570, 0.441, 341.333
# Average Creation Time for the 19 qubit group = 0.019 secs
# Average Elapsed Time for the 19 qubit group = 559.081 secs
# Average Execution Time for the 19 qubit group = 76.644 secs
# Average Fidelity for the 19 qubit group = 0.0
# Average AQ Fidelity for the 19 qubit group = 0.0
#
# ************
# Average Depth, ξ (xi) for the 20 qubit group = 611, 0.465
# Average Transpiled Depth, ξ (xi), 2q gates for the 20 qubit group = 630, 0.444, 379.333
# Average Creation Time for the 20 qubit group = 0.02 secs
# Average Elapsed Time for the 20 qubit group = 348.901 secs
# Average Execution Time for the 20 qubit group = 171.122 secs
# Average Fidelity for the 20 qubit group = 0.0
# Average AQ Fidelity for the 20 qubit group = 0.0
#
# ... execution complete at 2023-10-16 17:24:21
#
# Sample Circuit:
#          ┌───┐ ░                                      ░ ┌──────────┐ ░ ┌─┐   »
# q1650_0: ┤ H ├─░────────────────────────────────■─────░─┤0         ├─░─┤M├───»
#          ├───┤ ░                                │     ░ │          │ ░ └╥┘┌─┐»
# q1650_1: ┤ H ├─░─────────────────────────■──────┼─────░─┤1         ├─░──╫─┤M├»
#          ├───┤ ░                         │      │     ░ │          │ ░  ║ └╥┘»
# q1650_2: ┤ H ├─░──────────────────■──────┼──────┼─────░─┤2 inv_qft ├─░──╫──╫─»
#          ├───┤ ░                  │      │      │     ░ │          │ ░  ║  ║ »
# q1650_3: ┤ H ├─░───────────■──────┼──────┼──────┼─────░─┤3         ├─░──╫──╫─»
#          ├───┤ ░           │      │      │      │     ░ │          │ ░  ║  ║ »
# q1650_4: ┤ H ├─░────■──────┼──────┼──────┼──────┼─────░─┤4         ├─░──╫──╫─»
#          ├───┤ ░ ┌──┴──┐┌──┴──┐┌──┴──┐┌──┴──┐┌──┴───┐ ░ └──────────┘ ░  ║  ║ »
# q1650_5: ┤ X ├─░─┤ U^1 ├┤ U^2 ├┤ U^4 ├┤ U^8 ├┤ U^16 ├─░──────────────░──╫──╫─»
#          └───┘ ░ └─────┘└─────┘└─────┘└─────┘└──────┘ ░              ░  ║  ║ »
#   c30: 5/═══════════════════════════════════════════════════════════════╩══╩═»
#                                                                         0  1 »
# «
# «q1650_0: ─────────
# «
# «q1650_1: ─────────
# «         ┌─┐
# «q1650_2: ┤M├──────
# «         └╥┘┌─┐
# «q1650_3: ─╫─┤M├───
# «          ║ └╥┘┌─┐
# «q1650_4: ─╫──╫─┤M├
# «          ║  ║ └╥┘
# «q1650_5: ─╫──╫──╫─
# «          ║  ║  ║
# «  c30: 5/═╩══╩══╩═
# «          2  3  4
#
# Phase Operator 'U' =
#      ┌────────┐
# q_0: ┤ P(π/8) ├
#      └────────┘
#
# Inverse QFT Circuit =
#          ┌───┐                                                  ░      »
# q1652_0: ┤ H ├─────■───────────■───────────■────────────■───────░──────»
#          └───┘┌────┴─────┐     │           │            │       ░ ┌───┐»
# q1652_1: ─────┤ Rz(-π/2) ├─────┼───────────┼────────────┼───────░─┤ H ├»
#               └──────────┘┌────┴─────┐     │            │       ░ └───┘»
# q1652_2: ─────────────────┤ Rz(-π/4) ├─────┼────────────┼───────░──────»
#                           └──────────┘┌────┴─────┐      │       ░      »
# q1652_3: ─────────────────────────────┤ Rz(-π/8) ├──────┼───────░──────»
#                                       └──────────┘┌─────┴─────┐ ░      »
# q1652_4: ─────────────────────────────────────────┤ Rz(-π/16) ├─░──────»
#                                                   └───────────┘ ░      »
# «                                              ░                              »
# «q1652_0: ─────────────────────────────────────░──────────────────────────────»
# «                                              ░                              »
# «q1652_1: ─────■───────────■───────────■───────░──────────────────────────────»
# «         ┌────┴─────┐     │           │       ░ ┌───┐                        »
# «q1652_2: ┤ Rz(-π/2) ├─────┼───────────┼───────░─┤ H ├─────■───────────■──────»
# «         └──────────┘┌────┴─────┐     │       ░ └───┘┌────┴─────┐     │      »
# «q1652_3: ────────────┤ Rz(-π/4) ├─────┼───────░──────┤ Rz(-π/2) ├─────┼──────»
# «                     └──────────┘┌────┴─────┐ ░      └──────────┘┌────┴─────┐»
# «q1652_4: ────────────────────────┤ Rz(-π/8) ├─░──────────────────┤ Rz(-π/4) ├»
# «                                 └──────────┘ ░                  └──────────┘»
# «          ░                   ░       ░
# «q1652_0: ─░───────────────────░───────░─
# «          ░                   ░       ░
# «q1652_1: ─░───────────────────░───────░─
# «          ░                   ░       ░
# «q1652_2: ─░───────────────────░───────░─
# «          ░ ┌───┐             ░       ░
# «q1652_3: ─░─┤ H ├─────■───────░───────░─
# «          ░ └───┘┌────┴─────┐ ░ ┌───┐ ░
# «q1652_4: ─░──────┤ Rz(-π/2) ├─░─┤ H ├─░─
# «          ░      └──────────┘ ░ └───┘ ░

# %%
#%run amplitude-estimation/qiskit/ae_benchmark.py
import sys
sys.path.insert(1, "amplitude-estimation/qiskit")
import ae_benchmark
min_qubits=4
max_qubits=6
ae_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, max_circuits=max_circuits, num_shots=num_shots,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Amplitude Estimation Benchmark Program - Qiskit
# ... execution starting at 2023-10-16 17:24:23
# ************
# Executing [3] circuits with num_qubits = 4
# ************
# Executing [3] circuits with num_qubits = 5
# ************
# Executing [3] circuits with num_qubits = 6
# ************
# Average Depth, ξ (xi) for the 4 qubit group = 208, 0.432
# Average Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 165, 0.398, 84.0
# Average Creation Time for the 4 qubit group = 0.013 secs
# Average Elapsed Time for the 4 qubit group = 3.566 secs
# Average Execution Time for the 4 qubit group = 0.011 secs
# Average Fidelity for the 4 qubit group = 0.112
# Average AQ Fidelity for the 4 qubit group = 0.488
#
# ************
# Average Depth, ξ (xi) for the 5 qubit group = 479, 0.436
# Average Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 375, 0.404, 192.667
# Average Creation Time for the 5 qubit group = 0.019 secs
# Average Elapsed Time for the 5 qubit group = 7.197 secs
# Average Execution Time for the 5 qubit group = 0.016 secs
# Average Fidelity for the 5 qubit group = 0.046
# Average AQ Fidelity for the 5 qubit group = 0.285
#
# ************
# Average Depth, ξ (xi) for the 6 qubit group = 1017, 0.438
# Average Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 836, 0.407, 426.0
# Average Creation Time for the 6 qubit group = 0.062 secs
# Average Elapsed Time for the 6 qubit group = 4.356 secs
# Average Execution Time for the 6 qubit group = 0.037 secs
# Average Fidelity for the 6 qubit group = 0.036
# Average AQ Fidelity for the 6 qubit group = 0.136
#
# ... execution complete at 2023-10-16 17:24:34
#
# Sample Circuit:
#          ┌───┐                         ┌──────┐┌──────┐┌──────┐┌──────┐ ░ »
# q5033_0: ┤ H ├─────────────────────────┤0     ├┤0     ├┤0     ├┤0     ├─░─»
#          ├───┤         ┌──────┐┌──────┐│      ││      ││      ││      │ ░ »
# q5033_1: ┤ H ├─────────┤0     ├┤0     ├┤      ├┤      ├┤      ├┤      ├─░─»
#          ├───┤ ┌──────┐│      ││      ││      ││      ││      ││      │ ░ »
# q5033_2: ┤ H ├─┤0     ├┤      ├┤      ├┤  c_Q ├┤  c_Q ├┤  c_Q ├┤  c_Q ├─░─»
#          ├───┴┐│      ││  c_Q ││  c_Q ││      ││      ││      ││      │ ░ »
# q5032_0: ┤0   ├┤1 c_Q ├┤1     ├┤1     ├┤1     ├┤1     ├┤1     ├┤1     ├─░─»
#          │  A ││      ││      ││      ││      ││      ││      ││      │ ░ »
# q5032_1: ┤1   ├┤2     ├┤2     ├┤2     ├┤2     ├┤2     ├┤2     ├┤2     ├─░─»
#          └────┘└──────┘└──────┘└──────┘└──────┘└──────┘└──────┘└──────┘ ░ »
#   c80: 3/═════════════════════════════════════════════════════════════════»
#                                                                           »
# «         ┌──────────┐ ░ ┌─┐
# «q5033_0: ┤0         ├─░─┤M├──────
# «         │          │ ░ └╥┘┌─┐
# «q5033_1: ┤1 inv_qft ├─░──╫─┤M├───
# «         │          │ ░  ║ └╥┘┌─┐
# «q5033_2: ┤2         ├─░──╫──╫─┤M├
# «         └──────────┘ ░  ║  ║ └╥┘
# «q5032_0: ─────────────░──╫──╫──╫─
# «                      ░  ║  ║  ║
# «q5032_1: ─────────────░──╫──╫──╫─
# «                      ░  ║  ║  ║
# «  c80: 3/════════════════╩══╩══╩═
# «                         0  1  2
#
# Controlled Quantum Operator 'cQ' =
#
# q5215_0: ──■───
#          ┌─┴──┐
#     q_0: ┤0   ├
#          │  Q │
#     q_1: ┤1   ├
#          └────┘
#
# Quantum Operator 'Q' =
#                     ┌───────┐┌───┐          ┌───┐     ┌────┐
# q_0: ───────────────┤0      ├┤ X ├───────■──┤ X ├─────┤0   ├
#      ┌───┐┌───┐┌───┐│  A_dg │├───┤┌───┐┌─┴─┐├───┤┌───┐│  A │
# q_1: ┤ X ├┤ Z ├┤ X ├┤1      ├┤ X ├┤ H ├┤ X ├┤ H ├┤ X ├┤1   ├
#      └───┘└───┘└───┘└───────┘└───┘└───┘└───┘└───┘└───┘└────┘
#
# Amplitude Generator 'A' =
#                         ┌───┐
# q_0: ───────────────────┤ X ├
#      ┌───────┐┌───┐┌───┐└─┬─┘
# q_1: ┤ Ry(π) ├┤ X ├┤ X ├──■──
#      └───────┘└───┘└───┘
#
# Inverse QFT Circuit =
#          ┌───┐                         ░                   ░       ░
# q5035_0: ┤ H ├─────■───────────■───────░───────────────────░───────░─
#          └───┘┌────┴─────┐     │       ░ ┌───┐             ░       ░
# q5035_1: ─────┤ Rz(-π/2) ├─────┼───────░─┤ H ├─────■───────░───────░─
#               └──────────┘┌────┴─────┐ ░ └───┘┌────┴─────┐ ░ ┌───┐ ░
# q5035_2: ─────────────────┤ Rz(-π/4) ├─░──────┤ Rz(-π/2) ├─░─┤ H ├─░─
#                           └──────────┘ ░      └──────────┘ ░ └───┘ ░

# %%
#%run monte-carlo/qiskit/mc_benchmark.py
import sys
sys.path.insert(1, "monte-carlo/qiskit")
import mc_benchmark
min_qubits=4
max_qubits=6
mc_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, max_circuits=max_circuits, num_shots=num_shots,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Monte Carlo Sampling Benchmark Program - Qiskit
# ... using circuit method 2
# ... execution starting at 2023-10-16 17:24:36
# ************
# Executing [3] circuits with num_qubits = 4
# ************
# Executing [3] circuits with num_qubits = 5
# ************
# Average Depth, ξ (xi) for the 4 qubit group = 202, 0.398
# Average Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 208, 0.372, 96.0
# Average Creation Time for the 4 qubit group = 0.011 secs
# Average Elapsed Time for the 4 qubit group = 1.435 secs
# Average Execution Time for the 4 qubit group = 0.012 secs
# Average Fidelity for the 4 qubit group = 0.037
# Average AQ Fidelity for the 4 qubit group = 0.518
#
# ************
# Executing [3] circuits with num_qubits = 6
# ************
# Average Depth, ξ (xi) for the 5 qubit group = 468, 0.401
# Average Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 479, 0.377, 224.0
# Average Creation Time for the 5 qubit group = 0.015 secs
# Average Elapsed Time for the 5 qubit group = 3.166 secs
# Average Execution Time for the 5 qubit group = 0.014 secs
# Average Fidelity for the 5 qubit group = 0.021
# Average AQ Fidelity for the 5 qubit group = 0.266
#
# ************
# Average Depth, ξ (xi) for the 6 qubit group = 997, 0.402
# Average Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 1017, 0.38, 478.0
# Average Creation Time for the 6 qubit group = 0.021 secs
# Average Elapsed Time for the 6 qubit group = 2.196 secs
# Average Execution Time for the 6 qubit group = 0.053 secs
# Average Fidelity for the 6 qubit group = 0.007
# Average AQ Fidelity for the 6 qubit group = 0.131
#
# ... execution complete at 2023-10-16 17:24:40
#
# Sample Circuit:
#          ┌────┐┌──────┐┌──────┐┌──────┐┌──────┐┌──────┐┌──────┐┌──────┐ ░ »
# q5472_0: ┤0   ├┤1     ├┤1     ├┤1     ├┤1     ├┤1     ├┤1     ├┤1     ├─░─»
#          │  A ││      ││      ││      ││      ││      ││      ││      │ ░ »
# q5472_1: ┤1   ├┤2     ├┤2     ├┤2     ├┤2 c_Q ├┤2 c_Q ├┤2 c_Q ├┤2 c_Q ├─░─»
#          ├───┬┘│      ││  c_Q ││  c_Q ││      ││      ││      ││      │ ░ »
# q5473_0: ┤ H ├─┤  c_Q ├┤      ├┤      ├┤0     ├┤0     ├┤0     ├┤0     ├─░─»
#          ├───┤ │      ││      ││      │└──────┘└──────┘└──────┘└──────┘ ░ »
# q5473_1: ┤ H ├─┤      ├┤0     ├┤0     ├─────────────────────────────────░─»
#          ├───┤ │      │└──────┘└──────┘                                 ░ »
# q5473_2: ┤ H ├─┤0     ├─────────────────────────────────────────────────░─»
#          └───┘ └──────┘                                                 ░ »
#   c85: 3/═════════════════════════════════════════════════════════════════»
#                                                                           »
# «                      ░
# «q5472_0: ─────────────░──────────
# «                      ░
# «q5472_1: ─────────────░──────────
# «         ┌──────────┐ ░ ┌─┐
# «q5473_0: ┤0         ├─░─┤M├──────
# «         │          │ ░ └╥┘┌─┐
# «q5473_1: ┤1 inv_qft ├─░──╫─┤M├───
# «         │          │ ░  ║ └╥┘┌─┐
# «q5473_2: ┤2         ├─░──╫──╫─┤M├
# «         └──────────┘ ░  ║  ║ └╥┘
# «  c85: 3/════════════════╩══╩══╩═
# «                         0  1  2
#
# Controlled Quantum Operator 'cQ' =
#
# q5558_0: ──■───
#          ┌─┴──┐
#     q_0: ┤0   ├
#          │  Q │
#     q_1: ┤1   ├
#          └────┘
#
# Quantum Operator 'Q' =
#                     ┌───────┐┌───┐          ┌───┐     ┌────┐
# q_0: ───────────────┤0      ├┤ X ├───────■──┤ X ├─────┤0   ├
#      ┌───┐┌───┐┌───┐│  A_dg │├───┤┌───┐┌─┴─┐├───┤┌───┐│  A │
# q_1: ┤ X ├┤ Z ├┤ X ├┤1      ├┤ X ├┤ H ├┤ X ├┤ H ├┤ X ├┤1   ├
#      └───┘└───┘└───┘└───────┘└───┘└───┘└───┘└───┘└───┘└────┘
#
# Amplitude Generator 'A' =
#          ┌────┐┌────┐
# q5553_0: ┤0   ├┤0   ├
#          │  R ││  F │
# q5553_1: ┤1   ├┤1   ├
#          └────┘└────┘
#
# Distribution Generator 'R' =
#          ┌───┐
# q5554_0: ┤ H ├
#          └───┘
# q5554_1: ─────
#
#
# Function Generator 'F' =
#
# q5555_0: ──■──
#          ┌─┴─┐
# q5555_1: ┤ X ├
#          └───┘
#
# Inverse QFT Circuit =
#          ┌───┐                         ░                   ░       ░
# q5475_0: ┤ H ├─────■───────────■───────░───────────────────░───────░─
#          └───┘┌────┴─────┐     │       ░ ┌───┐             ░       ░
# q5475_1: ─────┤ Rz(-π/2) ├─────┼───────░─┤ H ├─────■───────░───────░─
#               └──────────┘┌────┴─────┐ ░ └───┘┌────┴─────┐ ░ ┌───┐ ░
# q5475_2: ─────────────────┤ Rz(-π/4) ├─░──────┤ Rz(-π/2) ├─░─┤ H ├─░─
#                           └──────────┘ ░      └──────────┘ ░ └───┘ ░

# %%
#%run hamiltonian-simulation/qiskit/hamiltonian_simulation_benchmark.py
import sys
sys.path.insert(1, "hamiltonian-simulation/qiskit")
import hamiltonian_simulation_benchmark
min_qubits=6
max_qubits=16
hamiltonian_simulation_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits,
                max_circuits=max_circuits, num_shots=num_shots,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Hamiltonian-Simulation Benchmark Program - Qiskit
# ... execution starting at 2023-10-16 17:24:42
# ************
# Executing [1] circuits with num_qubits = 6
# ************
# Executing [1] circuits with num_qubits = 7
# ************
# Average Depth, ξ (xi) for the 6 qubit group = 50, 0.283
# Average Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 44, 0.306, 45.0
# Average Creation Time for the 6 qubit group = 0.006 secs
# Average Elapsed Time for the 6 qubit group = 0.43 secs
# Average Execution Time for the 6 qubit group = 0.015 secs
# Average Fidelity for the 6 qubit group = 0.38
# Average AQ Fidelity for the 6 qubit group = 0.398
#
# ************
# Executing [1] circuits with num_qubits = 8
# ************
# Average Depth, ξ (xi) for the 7 qubit group = 50, 0.284
# Average Transpiled Depth, ξ (xi), 2q gates for the 7 qubit group = 44, 0.303, 54.0
# Average Creation Time for the 7 qubit group = 0.016 secs
# Average Elapsed Time for the 7 qubit group = 0.518 secs
# Average Execution Time for the 7 qubit group = 0.026 secs
# Average Fidelity for the 7 qubit group = 0.35
# Average AQ Fidelity for the 7 qubit group = 0.36
#
# ************
# Executing [1] circuits with num_qubits = 9
# ************
# Average Depth, ξ (xi) for the 8 qubit group = 50, 0.286
# Average Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 44, 0.312, 63.0
# Average Creation Time for the 8 qubit group = 0.007 secs
# Average Elapsed Time for the 8 qubit group = 0.576 secs
# Average Execution Time for the 8 qubit group = 0.014 secs
# Average Fidelity for the 8 qubit group = 0.302
# Average AQ Fidelity for the 8 qubit group = 0.308
#
# ************
# Executing [1] circuits with num_qubits = 10
# ************
# Average Depth, ξ (xi) for the 9 qubit group = 50, 0.287
# Average Transpiled Depth, ξ (xi), 2q gates for the 9 qubit group = 44, 0.309, 72.0
# Average Creation Time for the 9 qubit group = 0.007 secs
# Average Elapsed Time for the 9 qubit group = 0.744 secs
# Average Execution Time for the 9 qubit group = 0.031 secs
# Average Fidelity for the 9 qubit group = 0.239
# Average AQ Fidelity for the 9 qubit group = 0.243
#
# ************
# Executing [1] circuits with num_qubits = 11
# ************
# Average Depth, ξ (xi) for the 10 qubit group = 50, 0.288
# Average Transpiled Depth, ξ (xi), 2q gates for the 10 qubit group = 44, 0.315, 81.0
# Average Creation Time for the 10 qubit group = 0.009 secs
# Average Elapsed Time for the 10 qubit group = 0.753 secs
# Average Execution Time for the 10 qubit group = 0.081 secs
# Average Fidelity for the 10 qubit group = 0.194
# Average AQ Fidelity for the 10 qubit group = 0.196
#
# ************
# Executing [1] circuits with num_qubits = 12
# ************
# Average Depth, ξ (xi) for the 11 qubit group = 50, 0.288
# Average Transpiled Depth, ξ (xi), 2q gates for the 11 qubit group = 44, 0.312, 90.0
# Average Creation Time for the 11 qubit group = 0.084 secs
# Average Elapsed Time for the 11 qubit group = 1.593 secs
# Average Execution Time for the 11 qubit group = 0.85 secs
# Average Fidelity for the 11 qubit group = 0.166
# Average AQ Fidelity for the 11 qubit group = 0.167
#
# ************
# Executing [1] circuits with num_qubits = 13
# ************
# Average Depth, ξ (xi) for the 12 qubit group = 50, 0.289
# Average Transpiled Depth, ξ (xi), 2q gates for the 12 qubit group = 44, 0.317, 99.0
# Average Creation Time for the 12 qubit group = 0.856 secs
# Average Elapsed Time for the 12 qubit group = 1.649 secs
# Average Execution Time for the 12 qubit group = 0.734 secs
# Average Fidelity for the 12 qubit group = 0.139
# Average AQ Fidelity for the 12 qubit group = 0.14
#
# ************
# Executing [1] circuits with num_qubits = 14
# ************
# Average Depth, ξ (xi) for the 13 qubit group = 50, 0.29
# Average Transpiled Depth, ξ (xi), 2q gates for the 13 qubit group = 44, 0.315, 108.0
# Average Creation Time for the 13 qubit group = 0.738 secs
# Average Elapsed Time for the 13 qubit group = 2.326 secs
# Average Execution Time for the 13 qubit group = 1.347 secs
# Average Fidelity for the 13 qubit group = 0.113
# Average AQ Fidelity for the 13 qubit group = 0.113
#
# ************
# Executing [1] circuits with num_qubits = 15
# ************
# Average Depth, ξ (xi) for the 14 qubit group = 50, 0.29
# Average Transpiled Depth, ξ (xi), 2q gates for the 14 qubit group = 44, 0.319, 117.0
# Average Creation Time for the 14 qubit group = 0.013 secs
# Average Elapsed Time for the 14 qubit group = 3.724 secs
# Average Execution Time for the 14 qubit group = 2.77 secs
# Average Fidelity for the 14 qubit group = 0.102
# Average AQ Fidelity for the 14 qubit group = 0.102
#
# ************
# Executing [1] circuits with num_qubits = 16
# ************
# Average Depth, ξ (xi) for the 15 qubit group = 50, 0.29
# Average Transpiled Depth, ξ (xi), 2q gates for the 15 qubit group = 44, 0.317, 126.0
# Average Creation Time for the 15 qubit group = 0.014 secs
# Average Elapsed Time for the 15 qubit group = 3.742 secs
# Average Execution Time for the 15 qubit group = 2.622 secs
# Average Fidelity for the 15 qubit group = 0.085
# Average AQ Fidelity for the 15 qubit group = 0.085
#
# ************
# Average Depth, ξ (xi) for the 16 qubit group = 50, 0.291
# Average Transpiled Depth, ξ (xi), 2q gates for the 16 qubit group = 44, 0.32, 135.0
# Average Creation Time for the 16 qubit group = 0.014 secs
# Average Elapsed Time for the 16 qubit group = 5.301 secs
# Average Execution Time for the 16 qubit group = 4.687 secs
# Average Fidelity for the 16 qubit group = 0.079
# Average AQ Fidelity for the 16 qubit group = 0.079
#
# ... execution complete at 2023-10-16 17:25:00
#
# Sample Circuit:
#          ┌───┐ ░ ┌───────────────┐ ┌──────────────┐ ░ ┌─────────────┐»
# q5636_0: ┤ X ├─░─┤ Rx(-0.025609) ├─┤ Rz(0.009192) ├─░─┤0            ├»
#          └───┘ ░ ├───────────────┤┌┴──────────────┤ ░ │  xxyyzz_opt │»
# q5636_1: ──────░─┤ Rx(0.0025855) ├┤ Rz(-0.057871) ├─░─┤1            ├»
#          ┌───┐ ░ └┬──────────────┤└┬──────────────┤ ░ ├─────────────┤»
# q5636_2: ┤ X ├─░──┤ Rx(0.035773) ├─┤ Rz(0.051748) ├─░─┤0            ├»
#          └───┘ ░  ├──────────────┤ ├──────────────┤ ░ │  xxyyzz_opt │»
# q5636_3: ──────░──┤ Rx(0.038563) ├─┤ Rz(0.057288) ├─░─┤1            ├»
#          ┌───┐ ░  ├──────────────┤ ├──────────────┤ ░ ├─────────────┤»
# q5636_4: ┤ X ├─░──┤ Rx(0.049408) ├─┤ Rz(0.023959) ├─░─┤0            ├»
#          └───┘ ░  ├──────────────┤┌┴──────────────┤ ░ │  xxyyzz_opt │»
# q5636_5: ──────░──┤ Rx(-0.04161) ├┤ Rz(0.0059034) ├─░─┤1            ├»
#                ░  └──────────────┘└───────────────┘ ░ └─────────────┘»
#   c87: 6/════════════════════════════════════════════════════════════»
#                                                                      »
# «                         ░ ┌───────────────┐ ┌──────────────┐ ░ »
# «q5636_0: ────────────────░─┤ Rx(-0.025609) ├─┤ Rz(0.009192) ├─░─»
# «         ┌─────────────┐ ░ ├───────────────┤┌┴──────────────┤ ░ »
# «q5636_1: ┤0            ├─░─┤ Rx(0.0025855) ├┤ Rz(-0.057871) ├─░─»
# «         │  xxyyzz_opt │ ░ └┬──────────────┤└┬──────────────┤ ░ »
# «q5636_2: ┤1            ├─░──┤ Rx(0.035773) ├─┤ Rz(0.051748) ├─░─»
# «         ├─────────────┤ ░  ├──────────────┤ ├──────────────┤ ░ »
# «q5636_3: ┤0            ├─░──┤ Rx(0.038563) ├─┤ Rz(0.057288) ├─░─»
# «         │  xxyyzz_opt │ ░  ├──────────────┤ ├──────────────┤ ░ »
# «q5636_4: ┤1            ├─░──┤ Rx(0.049408) ├─┤ Rz(0.023959) ├─░─»
# «         └─────────────┘ ░  ├──────────────┤┌┴──────────────┤ ░ »
# «q5636_5: ────────────────░──┤ Rx(-0.04161) ├┤ Rz(0.0059034) ├─░─»
# «                         ░  └──────────────┘└───────────────┘ ░ »
# «  c87: 6/═══════════════════════════════════════════════════════»
# «                                                                »
# «         ┌─────────────┐                ░ ┌───────────────┐ ┌──────────────┐»
# «q5636_0: ┤0            ├────────────────░─┤ Rx(-0.025609) ├─┤ Rz(0.009192) ├»
# «         │  xxyyzz_opt │┌─────────────┐ ░ ├───────────────┤┌┴──────────────┤»
# «q5636_1: ┤1            ├┤0            ├─░─┤ Rx(0.0025855) ├┤ Rz(-0.057871) ├»
# «         ├─────────────┤│  xxyyzz_opt │ ░ └┬──────────────┤└┬──────────────┤»
# «q5636_2: ┤0            ├┤1            ├─░──┤ Rx(0.035773) ├─┤ Rz(0.051748) ├»
# «         │  xxyyzz_opt │├─────────────┤ ░  ├──────────────┤ ├──────────────┤»
# «q5636_3: ┤1            ├┤0            ├─░──┤ Rx(0.038563) ├─┤ Rz(0.057288) ├»
# «         ├─────────────┤│  xxyyzz_opt │ ░  ├──────────────┤ ├──────────────┤»
# «q5636_4: ┤0            ├┤1            ├─░──┤ Rx(0.049408) ├─┤ Rz(0.023959) ├»
# «         │  xxyyzz_opt │└─────────────┘ ░  ├──────────────┤┌┴──────────────┤»
# «q5636_5: ┤1            ├────────────────░──┤ Rx(-0.04161) ├┤ Rz(0.0059034) ├»
# «         └─────────────┘                ░  └──────────────┘└───────────────┘»
# «  c87: 6/═══════════════════════════════════════════════════════════════════»
# «                                                                            »
# «          ░ ┌─────────────┐                ░ ┌─┐
# «q5636_0: ─░─┤0            ├────────────────░─┤M├───────────────
# «          ░ │  xxyyzz_opt │┌─────────────┐ ░ └╥┘┌─┐
# «q5636_1: ─░─┤1            ├┤0            ├─░──╫─┤M├────────────
# «          ░ ├─────────────┤│  xxyyzz_opt │ ░  ║ └╥┘┌─┐
# «q5636_2: ─░─┤0            ├┤1            ├─░──╫──╫─┤M├─────────
# «          ░ │  xxyyzz_opt │├─────────────┤ ░  ║  ║ └╥┘┌─┐
# «q5636_3: ─░─┤1            ├┤0            ├─░──╫──╫──╫─┤M├──────
# «          ░ ├─────────────┤│  xxyyzz_opt │ ░  ║  ║  ║ └╥┘┌─┐
# «q5636_4: ─░─┤0            ├┤1            ├─░──╫──╫──╫──╫─┤M├───
# «          ░ │  xxyyzz_opt │└─────────────┘ ░  ║  ║  ║  ║ └╥┘┌─┐
# «q5636_5: ─░─┤1            ├────────────────░──╫──╫──╫──╫──╫─┤M├
# «          ░ └─────────────┘                ░  ║  ║  ║  ║  ║ └╥┘
# «  c87: 6/═════════════════════════════════════╩══╩══╩══╩══╩══╩═
# «                                              0  1  2  3  4  5
#
# XXYYZZ_opt =
#                        ┌───┐┌─────────────┐                    ┌───┐»
# q6536_0: ──────────────┤ X ├┤ Rz(-1.5603) ├──■─────────────────┤ X ├»
#          ┌────────────┐└─┬─┘└┬────────────┤┌─┴─┐┌─────────────┐└─┬─┘»
# q6536_1: ┤ Rz(1.5708) ├──■───┤ Ry(1.5603) ├┤ X ├┤ Ry(-1.5603) ├──■──»
#          └────────────┘      └────────────┘└───┘└─────────────┘     »
# «         ┌─────────────┐
# «q6536_0: ┤ Rz(-1.5708) ├
# «         └─────────────┘
# «q6536_1: ───────────────
# «

# %%
#%run vqe/qiskit/vqe_benchmark.py
import sys
sys.path.insert(1, "vqe/qiskit")
import vqe_benchmark
vqe_num_shots=4098
min_qubits=4
max_qubits=8
vqe_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, max_circuits=max_circuits, num_shots=vqe_num_shots,
                method=1,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Variational Quantum Eigensolver Benchmark Program - Qiskit
# ... using circuit method 1
# ... execution starting at 2023-10-16 17:25:01
# ************
# Executing [3] circuits with num_qubits = 4
# ************
# Executing [3] circuits with num_qubits = 6
# ************
# Executing [3] circuits with num_qubits = 8
# ************
# Average Depth, ξ (xi) for the 4 qubit group = 113, 0.442
# Average Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 68, 0.485, 48.0
# Average Creation Time for the 4 qubit group = 0.33 secs
# Average Elapsed Time for the 4 qubit group = 5.288 secs
# Average Execution Time for the 4 qubit group = 0.014 secs
# Average Fidelity for the 4 qubit group = 0.381
# Average AQ Fidelity for the 4 qubit group = 0.49
#
# ************
# Average Depth, ξ (xi) for the 6 qubit group = 475, 0.56
# Average Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 291, 0.58, 224.0
# Average Creation Time for the 6 qubit group = 1.683 secs
# Average Elapsed Time for the 6 qubit group = 14.102 secs
# Average Execution Time for the 6 qubit group = 0.03 secs
# Average Fidelity for the 6 qubit group = 0.018
# Average AQ Fidelity for the 6 qubit group = 0.083
#
# ************
# Average Depth, ξ (xi) for the 8 qubit group = 2056, 0.644
# Average Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 1273, 0.642, 1024.0
# Average Creation Time for the 8 qubit group = 8.028 secs
# Average Elapsed Time for the 8 qubit group = 5.209 secs
# Average Execution Time for the 8 qubit group = 0.087 secs
# Average Fidelity for the 8 qubit group = 0.001
# Average AQ Fidelity for the 8 qubit group = 0.055
#
# ... execution complete at 2023-10-16 17:25:20
#
# Sample Circuit:
#          ┌─────┐┌────────────────────┐┌────────────────────┐»
# q6595_0: ┤0    ├┤0                   ├┤0                   ├»
#          │     ││                    ││                    │»
# q6595_1: ┤1    ├┤1                   ├┤1                   ├»
#          │  Hf ││  Cluster Op (0, 1) ││  Cluster Op (2, 3) │»
# q6595_2: ┤2    ├┤2                   ├┤2                   ├»
#          │     ││                    ││                    │»
# q6595_3: ┤3    ├┤3                   ├┤3                   ├»
#          └─────┘└────────────────────┘└────────────────────┘»
#  meas: 4/═══════════════════════════════════════════════════»
#                                                             »
# «         ┌──────────────────────────┐ ░ ┌─┐
# «q6595_0: ┤0                         ├─░─┤M├─────────
# «         │                          │ ░ └╥┘┌─┐
# «q6595_1: ┤1                         ├─░──╫─┤M├──────
# «         │  Cluster Op (0, 1, 2, 3) │ ░  ║ └╥┘┌─┐
# «q6595_2: ┤2                         ├─░──╫──╫─┤M├───
# «         │                          │ ░  ║  ║ └╥┘┌─┐
# «q6595_3: ┤3                         ├─░──╫──╫──╫─┤M├
# «         └──────────────────────────┘ ░  ║  ║  ║ └╥┘
# « meas: 4/════════════════════════════════╩══╩══╩══╩═
# «                                         0  1  2  3
#
# Hartree Fock Generator 'Hf' =
#      ┌───┐
# q_0: ┤ X ├
#      └───┘
# q_1: ─────
#      ┌───┐
# q_2: ┤ X ├
#      └───┘
# q_3: ─────
#
#
# Cluster Operator Example 'Cluster Op' =
#             ┌─────┐       ┌───┐┌───┐┌───┐┌───┐┌─────────────┐┌───┐┌───┐»
# q_0: ───────┤ Sdg ├───────┤ H ├┤ X ├┤ X ├┤ X ├┤ Rz(-0.0258) ├┤ X ├┤ X ├»
#             ├─────┤       ├───┤└─┬─┘└─┬─┘└─┬─┘└─────────────┘└─┬─┘└─┬─┘»
# q_1: ───────┤ Sdg ├───────┤ H ├──■────┼────┼───────────────────┼────┼──»
#             ├─────┤       ├───┤       │    │                   │    │  »
# q_2: ───────┤ Sdg ├───────┤ H ├───────■────┼───────────────────┼────■──»
#      ┌──────┴─────┴──────┐├───┤            │                   │  ┌───┐»
# q_3: ┤ circuit-564964_dg ├┤ H ├────────────■───────────────────■──┤ H ├»
#      └───────────────────┘└───┘                                   └───┘»
# «           ┌───┐        ┌───┐         ┌───┐        ┌─────┐┌───┐┌───┐┌───┐┌───┐»
# «q_0: ──────┤ X ├────────┤ H ├─────────┤ S ├────────┤ Sdg ├┤ H ├┤ X ├┤ X ├┤ X ├»
# «           └─┬─┘        ├───┤         ├───┤        ├─────┤├───┤└─┬─┘└─┬─┘└─┬─┘»
# «q_1: ────────■──────────┤ H ├─────────┤ S ├────────┤ Sdg ├┤ H ├──■────┼────┼──»
# «           ┌───┐        ├───┤ ┌───────┴───┴───────┐└┬───┬┘└───┘       │    │  »
# «q_2: ──────┤ H ├────────┤ S ├─┤ circuit-564914_dg ├─┤ H ├─────────────■────┼──»
# «     ┌─────┴───┴──────┐┌┴───┴┐└───────┬───┬───────┘ └───┘                  │  »
# «q_3: ┤ circuit-564964 ├┤ Sdg ├────────┤ H ├────────────────────────────────■──»
# «     └────────────────┘└─────┘        └───┘                                   »
# «     ┌────────────┐┌───┐┌───┐┌───┐      ┌───┐        ┌───┐ »
# «q_0: ┤ Rz(0.0258) ├┤ X ├┤ X ├┤ X ├──────┤ H ├────────┤ S ├─»
# «     └────────────┘└─┬─┘└─┬─┘└─┬─┘      ├───┤        ├───┤ »
# «q_1: ────────────────┼────┼────■────────┤ H ├────────┤ S ├─»
# «                     │    │  ┌───┐┌─────┴───┴──────┐┌┴───┴┐»
# «q_2: ────────────────┼────■──┤ H ├┤ circuit-564914 ├┤ Sdg ├»
# «                     │  ┌───┐├───┤└────┬─────┬─────┘└┬───┬┘»
# «q_3: ────────────────■──┤ H ├┤ S ├─────┤ Sdg ├───────┤ H ├─»
# «                        └───┘└───┘     └─────┘       └───┘ »
# «            ┌─────┐       ┌───┐┌───┐┌───┐┌───┐┌─────────────┐┌───┐┌───┐┌───┐»
# «q_0: ───────┤ Sdg ├───────┤ H ├┤ X ├┤ X ├┤ X ├┤ Rz(-0.0258) ├┤ X ├┤ X ├┤ X ├»
# «     ┌──────┴─────┴──────┐├───┤└─┬─┘└─┬─┘└─┬─┘└─────────────┘└─┬─┘└─┬─┘└─┬─┘»
# «q_1: ┤ circuit-564870_dg ├┤ H ├──■────┼────┼───────────────────┼────┼────■──»
# «     └───────┬───┬───────┘└───┘       │    │                   │    │  ┌───┐»
# «q_2: ────────┤ H ├────────────────────■────┼───────────────────┼────■──┤ H ├»
# «             └───┘                         │                   │  ┌───┐├───┤»
# «q_3: ──────────────────────────────────────■───────────────────■──┤ H ├┤ S ├»
# «                                                                  └───┘└───┘»
# «     ┌───┐      ┌───┐              ┌─────┐        ┌───┐┌───┐┌───┐┌───┐»
# «q_0: ┤ H ├──────┤ S ├──────────────┤ Sdg ├────────┤ H ├┤ X ├┤ X ├┤ X ├»
# «     ├───┤┌─────┴───┴──────┐┌──────┴─────┴───────┐├───┤└─┬─┘└─┬─┘└─┬─┘»
# «q_1: ┤ H ├┤ circuit-564870 ├┤0                   ├┤ H ├──■────┼────┼──»
# «     ├───┤└────────────────┘│                    │├───┤       │    │  »
# «q_2: ┤ S ├──────────────────┤1 circuit-564826_dg ├┤ H ├───────■────┼──»
# «     └───┘                  │                    │├───┤            │  »
# «q_3: ───────────────────────┤2                   ├┤ H ├────────────■──»
# «                            └────────────────────┘└───┘               »
# «     ┌─────────────┐┌───┐┌───┐┌───┐┌───┐       ┌───┐       »
# «q_0: ┤ Rz(-0.0258) ├┤ X ├┤ X ├┤ X ├┤ H ├───────┤ S ├───────»
# «     └─────────────┘└─┬─┘└─┬─┘└─┬─┘├───┤┌──────┴───┴──────┐»
# «q_1: ─────────────────┼────┼────■──┤ H ├┤0                ├»
# «                      │    │  ┌───┐└───┘│                 │»
# «q_2: ─────────────────┼────■──┤ H ├─────┤1 circuit-564826 ├»
# «                      │  ┌───┐└───┘     │                 │»
# «q_3: ─────────────────■──┤ H ├──────────┤2                ├»
# «                         └───┘          └─────────────────┘»
# «     ┌───────────────────┐┌───┐┌───┐┌───┐┌───┐┌────────────┐┌───┐┌───┐┌───┐»
# «q_0: ┤ circuit-564788_dg ├┤ H ├┤ X ├┤ X ├┤ X ├┤ Rz(0.0258) ├┤ X ├┤ X ├┤ X ├»
# «     └──────┬─────┬──────┘├───┤└─┬─┘└─┬─┘└─┬─┘└────────────┘└─┬─┘└─┬─┘└─┬─┘»
# «q_1: ───────┤ Sdg ├───────┤ H ├──■────┼────┼──────────────────┼────┼────■──»
# «            ├─────┤       ├───┤       │    │                  │    │  ┌───┐»
# «q_2: ───────┤ Sdg ├───────┤ H ├───────■────┼──────────────────┼────■──┤ H ├»
# «            ├─────┤       ├───┤            │                  │  ┌───┐├───┤»
# «q_3: ───────┤ Sdg ├───────┤ H ├────────────■──────────────────■──┤ H ├┤ S ├»
# «            └─────┘       └───┘                                  └───┘└───┘»
# «     ┌───┐  ┌────────────────┐  ┌───────────────────┐┌───┐┌───┐┌───┐┌───┐»
# «q_0: ┤ H ├──┤ circuit-564788 ├──┤ circuit-564736_dg ├┤ H ├┤ X ├┤ X ├┤ X ├»
# «     ├───┤  └─────┬───┬──────┘  └──────┬─────┬──────┘├───┤└─┬─┘└─┬─┘└─┬─┘»
# «q_1: ┤ H ├────────┤ S ├────────────────┤ Sdg ├───────┤ H ├──■────┼────┼──»
# «     ├───┤┌───────┴───┴────────┐       └┬───┬┘       └───┘       │    │  »
# «q_2: ┤ S ├┤0                   ├────────┤ H ├────────────────────■────┼──»
# «     └───┘│  circuit-564729_dg │        ├───┤                         │  »
# «q_3: ─────┤1                   ├────────┤ H ├─────────────────────────■──»
# «          └────────────────────┘        └───┘                            »
# «     ┌────────────┐┌───┐┌───┐┌───┐       ┌───┐         ┌────────────────┐ »
# «q_0: ┤ Rz(0.0258) ├┤ X ├┤ X ├┤ X ├───────┤ H ├─────────┤ circuit-564736 ├─»
# «     └────────────┘└─┬─┘└─┬─┘└─┬─┘       ├───┤         └─────┬───┬──────┘ »
# «q_1: ────────────────┼────┼────■─────────┤ H ├───────────────┤ S ├────────»
# «                     │    │  ┌───┐┌──────┴───┴──────┐       ┌┴───┴┐       »
# «q_2: ────────────────┼────■──┤ H ├┤0                ├───────┤ Sdg ├───────»
# «                     │  ┌───┐└───┘│  circuit-564729 │┌──────┴─────┴──────┐»
# «q_3: ────────────────■──┤ H ├─────┤1                ├┤ circuit-564673_dg ├»
# «                        └───┘     └─────────────────┘└───────────────────┘»
# «     ┌───────────────────┐┌───┐┌───┐┌───┐┌───┐┌─────────────┐┌───┐┌───┐»
# «q_0: ┤ circuit-564687_dg ├┤ H ├┤ X ├┤ X ├┤ X ├┤ Rz(-0.0258) ├┤ X ├┤ X ├»
# «     ├───────────────────┤├───┤└─┬─┘└─┬─┘└─┬─┘└─────────────┘└─┬─┘└─┬─┘»
# «q_1: ┤ circuit-564680_dg ├┤ H ├──■────┼────┼───────────────────┼────┼──»
# «     └───────┬───┬───────┘└───┘       │    │                   │    │  »
# «q_2: ────────┤ H ├────────────────────■────┼───────────────────┼────■──»
# «             ├───┤                         │                   │  ┌───┐»
# «q_3: ────────┤ H ├─────────────────────────■───────────────────■──┤ H ├»
# «             └───┘                                                └───┘»
# «           ┌───┐        ┌───┐   ┌────────────────┐ ┌───────────────────┐┌───┐»
# «q_0: ──────┤ X ├────────┤ H ├───┤ circuit-564687 ├─┤ circuit-564631_dg ├┤ H ├»
# «           └─┬─┘        ├───┤   ├────────────────┤ ├───────────────────┤├───┤»
# «q_1: ────────■──────────┤ H ├───┤ circuit-564680 ├─┤ circuit-564624_dg ├┤ H ├»
# «           ┌───┐        ├───┤ ┌─┴────────────────┴┐└───────┬───┬───────┘└───┘»
# «q_2: ──────┤ H ├────────┤ S ├─┤ circuit-564617_dg ├────────┤ H ├─────────────»
# «     ┌─────┴───┴──────┐┌┴───┴┐└───────┬───┬───────┘        └───┘             »
# «q_3: ┤ circuit-564673 ├┤ Sdg ├────────┤ H ├──────────────────────────────────»
# «     └────────────────┘└─────┘        └───┘                                  »
# «     ┌───┐┌───┐┌───┐┌────────────┐┌───┐┌───┐┌───┐      ┌───┐       »
# «q_0: ┤ X ├┤ X ├┤ X ├┤ Rz(0.0258) ├┤ X ├┤ X ├┤ X ├──────┤ H ├───────»
# «     └─┬─┘└─┬─┘└─┬─┘└────────────┘└─┬─┘└─┬─┘└─┬─┘      ├───┤       »
# «q_1: ──■────┼────┼──────────────────┼────┼────■────────┤ H ├───────»
# «            │    │                  │    │  ┌───┐┌─────┴───┴──────┐»
# «q_2: ───────■────┼──────────────────┼────■──┤ H ├┤ circuit-564617 ├»
# «                 │                  │  ┌───┐├───┤└────────────────┘»
# «q_3: ────────────■──────────────────■──┤ H ├┤ S ├──────────────────»
# «                                       └───┘└───┘                  »
# «     ┌────────────────┐
# «q_0: ┤ circuit-564631 ├
# «     ├────────────────┤
# «q_1: ┤ circuit-564624 ├
# «     └────────────────┘
# «q_2: ──────────────────
# «
# «q_3: ──────────────────
# «

# %% [markdown]
# ## Final #AQ number

# %%
import sys
sys.path.insert(1, "_common")
import metrics

metrics.plot_all_app_metrics_aq(backend_id, do_all_plots=False, include_apps=None, is_individual=True)
